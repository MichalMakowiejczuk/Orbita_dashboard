# %%
from scripts.preprocess import load_data

# %%
df = load_data()
df.head()
# Out:
#    nr_startowy       nick  deklarowane  zrobione  DNF_km  dystans_km plec  \
# 0            2     Parker            5       2.0     NaN         250    M
# 1            3    Radek_1            5       2.0     NaN         250    M
# 2            4       Czaq            2       2.0     NaN         250    M
# 3            5  mykerynos            2       1.0     NaN         125    M
# 4            6    Krempy             1       1.0     NaN         125    M
#
#   typ_uczestnika pora_startu_z_DNS pora_startu    DNS  mniej_niz_1_orbita  \
# 0          stary         wieczorny   wieczorny  False               False
# 1          stary         wieczorny   wieczorny  False               False
# 2          stary             ranny       ranny  False               False
# 3          stary         wieczorny   wieczorny  False               False
# 4          stary             ranny       ranny  False               False
#
#    zrobione_pelne
# 0             2.0
# 1             2.0
# 2             2.0
# 3             1.0
# 4             1.0

# %%
df[df['mniej_niz_1_orbita']]
# Out:
#      nr_startowy        nick  deklarowane  zrobione  DNF_km  dystans_km plec  \
# 37            39       Czaja            1     0.240    30.0          30    M
# 39            41       Cinek            1     0.360    45.0          45    M
# 47            49        Tobi            3     0.296    37.0          37    M
# 62            64      Poldek            1     0.520    65.0          65    M
# 83            85     tadek.p            1     0.176    22.0          22    M
# 90            92  wielepiej             1     0.872   109.0         109    M
# 102          104      kwitek            1     0.240    30.0          30    K
# 114          116      wlodec            1     0.520    65.0          65    M
# 148          150     Mar Dzi            1     0.520    65.0          65    M
# 162          164    Stalinho            1     0.448    56.0          56    M
# 170          172      Grochu            2     0.448    56.0          56    M
# 204          206       MARCO            1     0.280    35.0          35    M
#
#     typ_uczestnika pora_startu_z_DNS pora_startu    DNS  mniej_niz_1_orbita  \
# 37           stary         wieczorny   wieczorny  False                True
# 39           stary             ranny       ranny  False                True
# 47           stary         wieczorny   wieczorny  False                True
# 62           stary             ranny       ranny  False                True
# 83           stary             ranny       ranny  False                True
# 90           stary             ranny       ranny  False                True
# 102          stary             ranny       ranny  False                True
# 114          stary         wieczorny   wieczorny  False                True
# 148           nowy         wieczorny   wieczorny  False                True
# 162           nowy         wieczorny   wieczorny  False                True
# 170           nowy         wieczorny   wieczorny  False                True
# 204           nowy             ranny       ranny  False                True
#
#      zrobione_pelne
# 37              0.0
# 39              0.0
# 47              0.0
# 62              0.0
# 83              0.0
# 90              0.0
# 102             0.0
# 114             0.0
# 148             0.0
# 162             0.0
# 170             0.0
# 204             0.0

# %%
df[df['DNS']]
# Out:
#      nr_startowy           nick  deklarowane  zrobione  DNF_km  dystans_km  \
# 14            16         M1chaL            1       0.0     NaN           0
# 22            24      Magdalena            2       0.0     NaN           0
# 41            43       Bart1985            2       0.0     NaN           0
# 43            45       Marcin Ż            3       0.0     NaN           0
# 56            58         elf_ik            1       0.0     NaN           0
# 68            70      danielek             2       0.0     NaN           0
# 75            77     sylwia1512            1       0.0     NaN           0
# 77            79  Miszcz Michał            1       0.0     NaN           0
# 78            80           Tash            1       0.0     NaN           0
# 80            82           Sito            2       0.0     NaN           0
# 84            86         piotrf            1       0.0     NaN           0
# 86            88    Impresario7            1       0.0     NaN           0
# 94            96         dobrus            3       0.0     NaN           0
# 99           101      Kilmister            2       0.0     NaN           0
# 101          103          Mista            1       0.0     NaN           0
# 106          108        Szyszek            1       0.0     NaN           0
# 112          114      PatrycjaK            2       0.0     NaN           0
# 115          117        Ewulas7            1       0.0     NaN           0
# 122          124         Magda             1       0.0     NaN           0
# 125          127      ŁukaszM90            5       0.0     NaN           0
# 126          128            Agi            5       0.0     NaN           0
# 128          130      LaFormela            5       0.0     NaN           0
# 136          138          Monia            1       0.0     NaN           0
# 138          140         Neezys            2       0.0     NaN           0
# 145          147           Karo            2       0.0     NaN           0
# 146          148     Marcin1313            2       0.0     NaN           0
# 160          162         Jezior            1       0.0     NaN           0
# 163          165       Cieniu10            1       0.0     NaN           0
# 174          176        kriskrt            1       0.0     NaN           0
# 176          178           lewy            1       0.0     NaN           0
# 184          186   Nonstopkolor            1       0.0     NaN           0
# 187          189      PopSylwia            1       0.0     NaN           0
# 189          191          Aga_G            1       0.0     NaN           0
# 191          193         Maniek            1       0.0     NaN           0
# 194          196           Karo            1       0.0     NaN           0
# 195          197       BigKasia            1       0.0     NaN           0
# 196          198       Michał_1            1       0.0     NaN           0
# 198          200          Marlo            1       0.0     NaN           0
# 199          201       Raszia13            1       0.0     NaN           0
# 209          211          Paveu            1       0.0     NaN           0
# 212          214         Milena            1       0.0     NaN           0
#
#     plec typ_uczestnika pora_startu_z_DNS pora_startu   DNS  \
# 14     M          stary               DNS   wieczorny  True
# 22     K          stary               DNS   wieczorny  True
# 41     M          stary               DNS       ranny  True
# 43     M          stary               DNS   wieczorny  True
# 56     K          stary               DNS       ranny  True
# 68     M          stary               DNS       ranny  True
# 75     K          stary               DNS       ranny  True
# 77     M          stary               DNS       ranny  True
# 78     M          stary               DNS       ranny  True
# 80     M          stary               DNS   wieczorny  True
# 84     M          stary               DNS       ranny  True
# 86     M          stary               DNS       ranny  True
# 94     M          stary               DNS       ranny  True
# 99     M          stary               DNS       ranny  True
# 101    M          stary               DNS       ranny  True
# 106    M          stary               DNS       ranny  True
# 112    K          stary               DNS       ranny  True
# 115    K          stary               DNS       ranny  True
# 122    K          stary               DNS       ranny  True
# 125    M           nowy               DNS   wieczorny  True
# 126    K           nowy               DNS   wieczorny  True
# 128    K           nowy               DNS   wieczorny  True
# 136    K           nowy               DNS       ranny  True
# 138    M           nowy               DNS   wieczorny  True
# 145    K           nowy               DNS       ranny  True
# 146    M           nowy               DNS       ranny  True
# 160    M           nowy               DNS       ranny  True
# 163    M           nowy               DNS       ranny  True
# 174    M           nowy               DNS       ranny  True
# 176    M           nowy               DNS       ranny  True
# 184    K           nowy               DNS       ranny  True
# 187    K           nowy               DNS       ranny  True
# 189    K           nowy               DNS       ranny  True
# 191    M           nowy               DNS       ranny  True
# 194    K           nowy               DNS       ranny  True
# 195    K           nowy               DNS       ranny  True
# 196    M           nowy               DNS       ranny  True
# 198    K           nowy               DNS       ranny  True
# 199    K           nowy               DNS       ranny  True
# 209    M          stary               DNS       ranny  True
# 212    K           nowy               DNS       ranny  True
#
#      mniej_niz_1_orbita
# 14                False
# 22                False
# 41                False
# 43                False
# 56                False
# 68                False
# 75                False
# 77                False
# 78                False
# 80                False
# 84                False
# 86                False
# 94                False
# 99                False
# 101               False
# 106               False
# 112               False
# 115               False
# 122               False
# 125               False
# 126               False
# 128               False
# 136               False
# 138               False
# 145               False
# 146               False
# 160               False
# 163               False
# 174               False
# 176               False
# 184               False
# 187               False
# 189               False
# 191               False
# 194               False
# 195               False
# 196               False
# 198               False
# 199               False
# 209               False
# 212               False

# %%
df[df['zrobione_pelne'] == 4]
# Out:
#     nr_startowy    nick  deklarowane  zrobione  DNF_km  dystans_km plec  \
# 34           36  Karpiu            5     4.096    12.0         512    M
#
#    typ_uczestnika pora_startu_z_DNS pora_startu    DNS  mniej_niz_1_orbita  \
# 34          stary         wieczorny   wieczorny  False               False
#
#     zrobione_pelne
# 34             4.0

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from math import sin, cos, sqrt, atan2, radians
import os
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import gpxpy
import gpxpy.gpx
from geopy.geocoders import Nominatim

# %%
GPX_FILE_PATH = "data/track/orbita25.gpx"

try:
    with open(GPX_FILE_PATH, 'r', encoding='utf-8') as gpx_file:
        gpx = gpxpy.parse(gpx_file)
except IOError:
    print("Couldn't open the input GPX file. Ensure it's in the 'input' dir.")
    raise()

# %%
def getLocationFromCoords(geolocator, latitude, longitude):
    """
    Converting GPS coordinates to location

     Parameter
     ----------
     geolocator : Nominatim API instance 
     latitude   : -
     longitude  : GPS coordinates in WGS84 projection

     Return
     ----------
     dictionnary of location features
    """
    coord = str(latitude)+","+str(longitude)
    location = geolocator.reverse(coord)
    return location.raw

def getCoordsFromLocation(geolocator, cityName):
    """
    Converting location to GPS coordinates 

     Parameter
     ----------
     geolocator : a Nominatim API instance 
     cityName   : name of location (string)

     Return
     ----------
     Location object
    """
    coords = geolocator.geocode(cityName)
    return coords

def getDistanceBetweenCoords(lat1, long1, lat2, long2):
    """
    Computing distance in km between 2 points 

     Parameter
     ----------
     lat1, long1 : latitude and longitude of first point 
     lat2, long2 : latitude and longitude of second point 

     Return
     ----------
     Distance in Km
    """
    earthRadius = 6371
    c = 0
    
    if all((lat1, long1, lat2, long2)):
        latFrom = radians(lat1)          
        lonFrom = radians(long1)
        latTo = radians(lat2)
        lonTo = radians(long2)
                
        dlon = lonTo - lonFrom
        dlat = latTo - latFrom
                
        a = sin(dlat / 2)**2 + cos(latFrom) * cos(latTo) * sin(dlon / 2)**2
        c = 2 * atan2(sqrt(a), sqrt(1 - a))

    return earthRadius * c

# %%
trackDf = []        #final dataframe initialization
segUnit = 0.25         #segment unit, here 1 km
km = 0              #cumulated km initialization

lastLat = None      #previously read latitude, None at the moment
lastLon = None      #previously read longitude, None at the moment

#We iterate on gpx structure then ...
for track in gpx.tracks:
    for segment in track.segments:
        for point in segment.points:

            # ... we compute the distance between current waypoint and last one
            distFromLastStep = getDistanceBetweenCoords(lastLat, lastLon, point.latitude, point.longitude)
            km = km + distFromLastStep  #cumulated km is updated
            
            # ... current segment determination
            segment = km // segUnit
            
            trackDf.append([segment, km, point.latitude, point.longitude, point.elevation])
            
            # ... current coords become previous ones
            lastLat = point.latitude
            lastLon = point.longitude


trackDf = pd.DataFrame(trackDf)  
trackDf.columns = ['segment', 'km', 'latitude', 'longitude', 'elevation']
trackDf.head(5)
# Out:
#    segment        km   latitude  longitude  elevation
# 0      0.0  0.000000  50.821123  19.143725     242.56
# 1      0.0  0.027560  50.821072  19.143341     242.59
# 2      0.0  0.054982  50.821021  19.142959     242.61
# 3      0.0  0.081710  50.820921  19.142613     242.68
# 4      0.0  0.097313  50.820833  19.142440     242.74

# %%
slopesDf = []                                     # dataframe initialization

# For each segment we calculated previously ...
for segment in trackDf['segment'].unique():
    
    #get first step of current segment then its elevation
    firstSt = trackDf.loc[trackDf[trackDf['segment'].eq(segment)]['km'].idxmin()]
    fromElv = firstSt['elevation'] 
    
    #get last step of current segment then its elevation
    lastSt = trackDf.loc[trackDf[trackDf['segment'].eq(segment)]['km'].idxmax()]
    toElv = lastSt['elevation'] 
 
    #determine current segment lenght (in km)
    segmentLength = trackDf[trackDf['segment'].eq(segment)]['km'].max() - trackDf[trackDf['segment'].eq(segment)]['km'].min()
    
    #calculate slope of current segment(in %)
    segmentSlope = (toElv - fromElv) / (segmentLength * 1000) * 100
    
    slopesDf.append([segment, segmentSlope])
    
    
slopesDf = pd.DataFrame(slopesDf)  
slopesDf.columns = ['segment', 'slope']
slopesDf
# Out:
#      segment     slope
# 0        0.0  0.628205
# 1        1.0  1.210568
# 2        2.0  0.125844
# 3        3.0 -0.645439
# 4        4.0 -0.865375
# ..       ...       ...
# 497    497.0  0.602061
# 498    498.0 -0.111165
# 499    499.0 -1.060484
# 500    500.0 -0.651658
# 501    501.0 -0.032574
#
# [502 rows x 2 columns]

# %%
trackDf = pd.merge(trackDf, slopesDf, on='segment')
trackDf.head()
# Out:
#    segment        km   latitude  longitude  elevation     slope
# 0      0.0  0.000000  50.821123  19.143725     242.56  0.628205
# 1      0.0  0.027560  50.821072  19.143341     242.59  0.628205
# 2      0.0  0.054982  50.821021  19.142959     242.61  0.628205
# 3      0.0  0.081710  50.820921  19.142613     242.68  0.628205
# 4      0.0  0.097313  50.820833  19.142440     242.74  0.628205

# %%
# Nomatim API instanciation
geolocator = Nominatim(user_agent="MyApp")

# coords to location conversion
getLocationFromCoords(geolocator, 50.821123, 18.143725)
# Out:
# {'place_id': 170109501,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#  'osm_type': 'way',
#  'osm_id': 372623514,
#  'lat': '50.8178104',
#  'lon': '18.1445040',
#  'class': 'amenity',
#  'type': 'fuel',
#  'place_rank': 30,
#  'importance': 4.698939497973628e-05,
#  'addresstype': 'amenity',
#  'name': 'Lotos',
#  'display_name': 'Lotos, Opolska, Pociecha, Bierdzany, gmina Turawa, powiat opolski, województwo opolskie, 46-046, Polska',
#  'address': {'amenity': 'Lotos',
#   'road': 'Opolska',
#   'hamlet': 'Pociecha',
#   'village': 'Bierdzany',
#   'municipality': 'gmina Turawa',
#   'county': 'powiat opolski',
#   'state': 'województwo opolskie',
#   'ISO3166-2-lvl4': 'PL-16',
#   'postcode': '46-046',
#   'country': 'Polska',
#   'country_code': 'pl'},
#  'boundingbox': ['50.8177543', '50.8178664', '18.1444102', '18.1445977']}

# %%
placesDf = []
placeLastKm = {}   # klucz: nazwa miejscowości, wartość: ostatni km w którym wystąpiła
min_distance_km = 5  # minimalny dystans pomiędzy kolejnymi etykietami tej samej miejscowości
placeGroup = 0

for segment in trackDf['segment'].unique():
    segment_df = trackDf[trackDf['segment'] == segment]
    row = segment_df.loc[segment_df['km'].idxmin()]
    fromLat = row['latitude']
    fromLong = row['longitude']
    fromElv = row['elevation']
    fromKm = row['km']

    try:
        location = getLocationFromCoords(geolocator, fromLat, fromLong)
        address = location['address']

        placeName = (
            address.get('city') or
            address.get('town') or
            address.get('village') or
            'Unknown'
        )

        if placeName == 'Unknown':
            continue  # pomijamy nieznane miejsca

        # jeśli miejscowość jest nowa lub jest dalej niż min_distance_km od ostatniego wystąpienia
        if (placeName not in placeLastKm) or (fromKm - placeLastKm[placeName] >= min_distance_km):
            placeGroup += 1
            placeLastKm[placeName] = fromKm
            placesDf.append([segment, placeName, fromElv, fromKm, placeGroup])

    except Exception as e:
        print(f"Błąd geolokalizacji dla segmentu {segment}: {e}")
        continue

placesDf = pd.DataFrame(placesDf, columns=['segment', 'place', 'elevation', 'km', 'group'])

# %%
placesDf = placesDf[placesDf['place'] != 'Unknown']
placesDf = placesDf.sort_values(['group', 'km']).drop_duplicates(subset=['place'], keep='first')

# %%
slopesTable = [lambda x: x < 2, 
               lambda x: (x >= 2) & (x < 4),
               lambda x: (x >= 4) & (x < 5),
               lambda x: (x >= 5) & (x < 8),
               lambda x: x >= 8,]

# slopes associated colors
slopesColor = ['palegreen', 'yellow', 'orange', 'orangered', 'maroon']

# slopes legend
slopesDescr = ['inf 2%', '2 ~ 4%', '4 ~ 5%', '5 ~ 8%', 'sup 8%']

# %%
def smoothProfile(signal, L=10):
    res = np.copy(signal) 
    for i in range (1,len(signal)-1): 
        L_g = min(i,L) 
        L_d = min(len(signal)-i-1,L) 
        Li=min(L_g,L_d)
        res[i]=np.sum(signal[i-Li:i+Li+1])/(2*Li+1)
    return res

# %%
legend = []                                # legend initialization
style = dict(size=10, color='gray')        # style used for annotations

# We first define the canvas, then axis (right and top ones will be hidden)
fig, ax = plt.subplots(figsize=(12,4))
plt.xlabel("Kilometers")
plt.ylabel("Elevation")
ax.spines[['right', 'top']].set_visible(False)

# Rendering of backhround gray curve (for a 3D effect)
# This curve is shifted 0.5km further and 15m above
plt.fill_between(trackDf['km']+0.5, smoothProfile(trackDf['elevation'])+15, color='gray', zorder=0)

# For each slope category we defined, profile is filled and legend is updated
for i in range(0, len(slopesTable)):
    plt.fill_between(trackDf['km'], smoothProfile(trackDf['elevation']), where = (slopesTable[i])(trackDf['slope']), color=slopesColor[i], zorder=1)
    legend.append(mpatches.Patch(color=slopesColor[i], label=slopesDescr[i]))

# We want annotations of place names to be over profile 
annotationsAnchor = trackDf['elevation'].max() * 1.1

# Place names annotation (every 4km, except for start and finish)
min_distance_km = 5
last_label_km = -min_distance_km  # tak, żeby pierwszy punkt zawsze przeszedł

for index, row in placesDf.iterrows():
    if row['km'] - last_label_km >= min_distance_km:
        ax.annotate(
            row['place'],
            xy=(row['km'], row['elevation']),
            xytext=(row['km'], annotationsAnchor),
            arrowprops=dict(arrowstyle="-", color='lightgray'),
            horizontalalignment='center',
            rotation=90,
            **style
        )
        last_label_km = row['km']
    
# Shrink current axis by 20%
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])

# Put the legend to the right of the current axis
ax.legend(handles=legend, loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()
